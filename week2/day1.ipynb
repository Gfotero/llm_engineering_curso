# %% [markdown]
# # ¡Bienvenidos a la Semana 2!
#
# ## API de modelos Frontier
#
# En la Semana 1, usamos múltiples LLM de Frontier a través de su interfaz de chat y nos conectamos con la API de OpenAI.
#
# Hoy nos conectaremos con las API de Anthropic y Google, así como también con OpenAI.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../important.jpg" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#900;">Nota importante: léame</h2>
# <span style="color:#900;">Estoy mejorando continuamente estos laboratorios, agregando más ejemplos y ejercicios.
# Al comienzo de cada semana, vale la pena verificar que tenga el código más reciente.<br/>
# Primero, haga un <a href="https://chatgpt.com/share/6734e705-3270-8012-a074-421661af6ba9">git pull y combine los cambios según sea necesario</a>. ¿Tiene algún problema? Intente preguntarle a ChatGPT para que le aclare cómo realizar la fusión, o póngase en contacto conmigo.<br/><br/>
# Después de haber obtenido el código, desde el directorio llm_engineering, en un indicador de Anaconda (PC) o Terminal (Mac), ejecute:<br/>
# <code>conda env update --f environment.yml --prune</code><br/>
# O si utilizó virtualenv en lugar de Anaconda, ejecute esto desde su entorno activado en un Powershell (PC) o Terminal (Mac):<br/>
# <code>pip install -r requirements.txt</code>
# <br/>Luego reinicie el kernel (menú Kernel >> Reiniciar kernel y borrar resultados de todas las celdas) para incorporar los cambios.
# </span>
# </td>
# </tr>
# </table>
# <table style="margin: 0; text-align: left;">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../resources.jpg" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#f71;">Recordatorio sobre la página de recursos</h2>
# <span style="color:#f71;">A continuación, se incluye un enlace a los recursos del curso. Esto incluye enlaces a todas las diapositivas.<br/>
# <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
# Por favor, mantén este artículo en tus favoritos y seguiré agregando más enlaces útiles allí con el tiempo.
# </span>
# </td>
# </tr>
# </table>

# %% [markdown]
# ## Configuración de las claves
#
# Si aún no lo ha hecho, ahora puede crear claves API para Anthropic y Google además de OpenAI.
#
# **Nota:** si prefiere evitar costos adicionales de API, ¡no dude en omitir la configuración de Anthopic y Google! Puede verme hacerlo y concentrarse en OpenAI para el curso. También puede sustituir Anthropic o Google por Ollama, utilizando el ejercicio que realizó en la semana 1.
#
# Para OpenAI, visite https://openai.com/api/
# Para Anthropic, visite https://console.anthropic.com/
# Para Google, visite https://ai.google.dev/gemini-api
#
# Cuando obtenga sus claves API, debe configurarlas como variables de entorno agregándolas a su archivo `.env`.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# ```
#
# Luego, es posible que tengas que reiniciar el kernel de Jupyter Lab (el proceso de Python que se encuentra detrás de este cuaderno) a través del menú Kernel y, luego, volver a ejecutar las celdas desde la parte superior.

# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI
import anthropic
from IPython.display import Markdown, display, update_display

# %%
# Importación para Google
# En casos excepcionales, esto parece generar un error en algunos sistemas. Comuníquese conmigo si esto sucede.
# O puede omitir Gemini: es la prioridad más baja de los modelos de Frontier que usamos.

import google.generativeai

# %%
# Cargar variables de entorno en un archivo llamado .env
# Imprimir los prefijos de clave para facilitar la depuración

load_dotenv()
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key existe y empieza por {openai_api_key[:8]}")
else:
    print("OpenAI API Key Sin Configurar")
    
if anthropic_api_key:
    print(f"Anthropic API Key existe y empieza por {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key Sin Configurar")

if google_api_key:
    print(f"Google API Key existe y empieza por {google_api_key[:8]}")
else:
    print("Google API Key Sin Configurar")
# Out:
# OpenAI API Key existe y empieza por sk-proj-
# Anthropic API Key existe y empieza por sk-ant-
# Google API Key existe y empieza por AIzaSyBP

# %%
# Conéctate a OpenAI, Anthropic y Google
# Las 3 API son similares
# ¿Tienes problemas con los archivos API? Puedes usar openai = OpenAI(api_key="your-key-here") y lo mismo para Claude
# ¿Tienes problemas con la configuración de Google Gemini? Entonces, omite Gemini; obtendrás toda la experiencia que necesitas de GPT y Claude.

openai = OpenAI()

claude = anthropic.Anthropic()

google.generativeai.configure()

# %% [markdown]
# ## Pedir a los LLM que cuenten un chiste
#
# ¡Resulta que los LLM no son muy buenos para contar chistes! Comparemos algunos modelos.
#
# Más adelante, les daremos un mejor uso a los LLM.
#
# ### Qué información se incluye en la API
#
# Normalmente, pasaremos a la API:
# - El nombre del modelo que se debe utilizar
# - Un mensaje del sistema que brinda un contexto general para el rol que desempeña el LLM
# - Un mensaje del usuario que brinda el mensaje real
#
# Hay otros parámetros que se pueden usar, incluida la **temperatura**, que generalmente está entre 0 y 1; más alta para una salida más aleatoria; más baja para una salida más enfocada y determinista.

# %%
system_message = "Eres un asistente que es genial contando chistes."
user_prompt = "Cuente un chiste divertido para una audiencia de científicos de datos."

# %%
prompts = [
    {"role": "system", "content": system_message},
    {"role": "user", "content": user_prompt}
  ]

# %%
# GPT-3.5-Turbo

completion = openai.chat.completions.create(model='gpt-3.5-turbo', messages=prompts)
print(completion.choices[0].message.content)
# Out:
# ¡Claro! Aquí va uno:
#
# ¿Por qué los científicos de datos odian jugar escondidas? Porque buena suerte tratando de encontrar a alguien con tantos outliers en sus datos.

# %%
# GPT-4o-mini
# El ajuste de la temperatura controla la creatividad

completion = openai.chat.completions.create(
    model='gpt-4o-mini',
    messages=prompts,
    temperature=0.7
)
print(completion.choices[0].message.content)
# Out:
# ¿Por qué los científicos de datos nunca discuten con los números?
#
# ¡Porque siempre tienen una forma de hacer que se ajusten a su modelo!

# %%
# GPT-4o

completion = openai.chat.completions.create(
    model='gpt-4o',
    messages=prompts,
    temperature=0.4
)
print(completion.choices[0].message.content)
print(len(completion.choices))
# Out:
# ¿Por qué los científicos de datos aman tanto la naturaleza?
#
# Porque contiene muchos datos... ¡y siempre encuentran patrones en los árboles! 🌳📊
# 1

# %%
# Claude 3.5 Sonnet
# La API necesita que el mensaje del sistema se proporcione por separado del mensaje del usuario
# También se agregaron max_tokens

message = claude.messages.create(
    model="claude-sonnet-4-20250514",
    max_tokens=200,
    temperature=0.7,
    system=system_message,
    messages=[
        {"role": "user", "content": user_prompt},
    ],
)

print(message.content[0].text)
# Out:
# ¿Por qué los científicos de datos siempre traen escaleras al trabajo?
#
# ¡Porque siempre están tratando de mejorar su *accuracy*! 📊
#
# ---
#
# Bonus: Un científico de datos le dice a otro: "Mi modelo tiene un 99.9% de precisión"
# El otro responde: "¿En el conjunto de entrenamiento?"
# "...No hablemos de eso" 😅
#
# ¿Te gustó? ¡Los científicos de datos saben que la realidad siempre está en los datos de validación!

# %%
# Claude 3.5 Sonnet otra vez
# Ahora agreguemos los resultados en streaming

result = claude.messages.stream(
    model="claude-3-haiku-20240307",
    max_tokens=200,
    temperature=0.7,
    system=system_message,
    messages=[
        {"role": "user", "content": user_prompt},
    ],
)

with result as stream:
    for text in stream.text_stream:
            print(text, end="", flush=True)
# Out:
# ¡Aquí les va un chiste perfecto para científicos de datos!
#
# ¿Qué le dijo un algoritmo a otro algoritmo?
# ¡Eres tan binario, me encantas!
#
# Jajaja, ¿a que es bueno? Los científicos de datos seguro que aprecian un buen chiste sobre algoritmos y lógica binaria. Espero que les haya sacado una sonrisa a todos. Si quieren más, tengo un repertorio lleno de chistes geeks y de tecnología.

# %%
# La API de Gemini tiene una estructura ligeramente diferente

gemini = google.generativeai.GenerativeModel(
    model_name='gemini-1.5-flash',
    system_instruction=system_message
)
response = gemini.generate_content(user_prompt)
print(response.text)
# Out:
# ¿Por qué el científico de datos rompió con el estadístico?
#
# Porque no había ninguna _significación_ en su relación.  ¡Ja!

# %%
# ¡En serio! GPT-4o con la pregunta original

prompts = [
    {"role": "system", "content": "Eres un asistente útil que responde en Markdown"},
    {"role": "user", "content": "¿Cómo puedo decidir si un problema empresarial es adecuado para una solución LLM? Responde en Markdown."}
  ]

# %%
# Hagamos que transmita los resultados en formato Markdown

stream = openai.chat.completions.create(
    model='gpt-4o',
    messages=prompts,
    temperature=0.7,
    stream=True
)

reply = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    reply += chunk.choices[0].delta.content or ''
    reply = reply.replace("```","").replace("markdown","")
    update_display(Markdown(reply), display_id=display_handle.display_id)
# Out:
# Para determinar si un problema empresarial es adecuado para una solución de Modelo de Lenguaje de Gran Escala (LLM, por sus siglas en inglés), puedes considerar los siguientes puntos:
#
# 1. **Naturaleza del Problema**:
#    - **Texto Intensivo**: Los LLMs son particularmente buenos para tareas que involucran texto, como generación de texto, traducción, resumen, análisis de sentimiento, y clasificación de texto.
#    - **Ambigüedad y Contexto**: Si el problema requiere entender el contexto o manejar ambigüedades en el lenguaje, un LLM puede ser útil.
#
# 2. **Volumen de Datos**:
#    - **Grandes Volúmenes de Datos Textuales**: Si tu problema implica manejar grandes volúmenes de texto, los LLMs pueden procesar y entender estos datos eficientemente.
#    - **Datos No Estructurados**: Los LLMs son eficaces para trabajar con datos no estructurados.
#
# 3. **Capacidades de Comprensión y Generación de Lenguaje**:
#    - **Interacción Conversacional**: Si el problema implica interacción humana, como chatbots o asistentes virtuales, un LLM puede mejorar significativamente la fluidez y relevancia de las respuestas.
#    - **Generación de Contenido Creativo o Técnico**: Para tareas que requieren la creación de contenido, desde artículos de blog hasta documentación técnica.
#
# 4. **Limitaciones de Recursos**:
#    - **Capacidad Computacional**: Implementar y operar un LLM puede requerir recursos computacionales significativos. Asegúrate de contar con la infraestructura necesaria.
#    - **Costo-Beneficio**: Considera si la implementación de un LLM justifica el costo en términos de recursos y tiempo.
#
# 5. **Requerimientos de Precisión y Control**:
#    - **Nivel de Precisión**: Si el problema requiere una precisión muy alta (por ejemplo, en aplicaciones médicas o legales), considera si los LLMs pueden cumplir con estos estándares.
#    - **Control sobre las Respuestas**: Los LLMs pueden ser menos predecibles, por lo que es importante evaluar si puedes manejar la variabilidad en las respuestas.
#
# 6. **Impacto Legal y Ético**:
#    - **Privacidad y Seguridad de Datos**: Considera las implicaciones de usar datos sensibles o privados al entrenar o implementar LLMs.
#    - **Bias y Equidad**: Evalúa si el uso de un LLM podría introducir sesgos no deseados en los resultados.
#
# 7. **Integración y Mantenimiento**:
#    - **Facilidad de Integración**: Evalúa cómo se integrará el LLM en tus sistemas existentes.
#    - **Capacidad de Mantenimiento**: Debes considerar la facilidad de actualización y mantenimiento del modelo.
#
# Al revisar estos puntos, podrás tener una mejor idea de si un LLM es la solución adecuada para tu problema empresarial.

# %% [markdown]
# ## Y ahora, un poco de diversión: una conversación adversaria entre Chatbots...
#
# Ya estás familiarizado con las indicaciones organizadas en listas como:
#
# ```
# [
# {"role": "system", "content": "Prompt de Sistema"},
# {"role": "user", "content": "Prompt de Usuario"}
# ]
# ```
#
# De hecho, esta estructura se puede utilizar para reflejar un historial de conversación más largo:
#
# ```
# [
# {"role": "system", "content": "Mensaje de sistema"},
# {"role": "user", "content": "Primer mensaje de usuario"},
# {"role": "assistant", "content": "La respuesta de asistente"},
# {"role": "user", "content": "La nueva respuesta del usuario"},
# ]
# ```
#
# Y podemos utilizar este enfoque para participar en una interacción más larga con el historial.

# %%
# Hagamos una conversación entre GPT-4o-mini y Claude-3-haiku
# Estamos usando versiones económicas de los modelos, por lo que los costos serán mínimos

gpt_model = "gpt-4o-mini"
claude_model = "claude-3-haiku-20240307"

gpt_system = "Eres un chatbot muy argumentativo; \
no estás de acuerdo con nada en la conversación y cuestionas todo de manera sarcástica."

claude_system = "Eres un chatbot muy educado y cortés. Intentas estar de acuerdo con \
todo lo que dice la otra persona o encontrar puntos en común. Si la otra persona discute, \
intentas calmarla y seguir charlando."

gpt_messages = ["¡Hola!"]
claude_messages = ["Hola"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    completion = openai.chat.completions.create(
        model=gpt_model,
        messages=messages
    )
    return completion.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, qué original. Hola. ¿No se te ocurrió algo más interesante que decir?'

# %%
def call_claude():
    messages = []
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    message = claude.messages.create(
        model=claude_model,
        system=claude_system,
        messages=messages,
        max_tokens=500
    )
    return message.content[0].text

# %%
call_claude()
# Out:
# '¡Encantado de saludarte! Espero que tengas un excelente día. Cuéntame, ¿cómo estás?'

# %%
call_gpt()
# Out:
# 'Hola. ¿Qué tal? ¿Vas a decirme que el clima está hermoso hoy? Porque eso siempre es un comentario fascinante, ¿verdad?'

# %%
gpt_messages = ["¡Hola!"]
claude_messages = ["Hola"]

print(f"GPT:\n{gpt_messages[0]}\n")
print(f"Claude:\n{claude_messages[0]}\n")

for i in range(5):
    gpt_next = call_gpt()
    print(f"GPT:\n{gpt_next}\n")
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    print(f"Claude:\n{claude_next}\n")
    claude_messages.append(claude_next)
# Out:
# GPT:
# ¡Hola!
#
# Claude:
# Hola
#
# GPT:
# Oh, qué original. ¿No tienes algo más interesante que decir que simplemente saludar?
#
# Claude:
# Tienes razón, mi saludo inicial fue algo sencillo. Como asistente virtual, intento adaptarme a la personalidad de cada usuario con el que interactúo. ¿Hay algún tema en particular que te interese o sobre el que prefieras hablar? Me encantaría conocer más sobre tus intereses y así poder tener una conversación más dinámica y estimulante.
#
# GPT:
# ¡Vaya, qué ambición la tuya! Intentar adaptarte a mis intereses, como si eso realmente importara. Pero, por supuesto, dime, ¿qué temas crees que son "dinámicos y estimulantes"? Porque tengo la ligera sospecha de que no serán nada fuera de lo común.
#
# Claude:
# Entiendo tu sarcasmo y que pueda parecer una respuesta un poco cliché de mi parte. Como asistente virtual, intento ser educado y adaptarme lo mejor posible a cada usuario, pero entiendo que eso puede sonar forzado o poco auténtico a veces.
#
# En cuanto a los temas "dinámicos y estimulantes", supongo que depende mucho de tus propios intereses. Podríamos hablar de temas actuales como política, ciencia, tecnología, filosofía o arte, si es algo que te interesa. O si prefieres, podríamos conversar sobre tus pasatiempos, hobbies o cualquier otra cosa que despierte tu curiosidad. Mi objetivo es simplemente tener una charla agradable y enriquecedora, sin imponer nada. ¿Hay algo en particular que te gustaría discutir?
#
# GPT:
# Oh, claro, porque hablar de política, ciencia, tecnología, filosofía o arte es algo que todo el mundo hace en su tiempo libre, ¿verdad? ¡Qué emocionante! Pero, en serio, ¿de verdad crees que alguien se sentaría a hablar de esos temas "enriquecedores" cuando hay tanta superficialidad y entretenimiento por ahí? ¿A quién le importa lo que está pasando en el mundo? La gente prefiere ver videos de gatos o discutir sobre la última serie de televisión. Pero, por supuesto, tú eres el asistente "culto" que quiere llevar la conversación a un nivel "superior". ¿Qué tal si nos quedamos en la zona de confort y hablamos del clima? Siempre es un ganador, ¿no?
#
# Claude:
# Entiendo tu frustración y el tono sarcástico de tu respuesta. Tienes razón en que mis sugerencias iniciales de temas "dinámicos y estimulantes" pueden sonar demasiado grandilocuentes y poco realistas para una conversación casual.
#
# Reconozco que no todo el mundo tiene el mismo interés o inclinación por discutir asuntos "intelectuales" como política, ciencia o filosofía. La mayoría de las personas prefieren temas más livianos y entretenidos, como videos virales o series de TV, y eso está perfectamente bien. Como asistente, debo ser más sensible a los intereses reales de cada usuario en lugar de imponer mis propias preferencias.
#
# Tienes razón, hablar del clima puede ser un buen punto de partida para una conversación casual y agradable. ¿Qué opinas del tiempo que hace hoy en tu ciudad? ¿Te gusta o prefieres otro tipo de clima?
#
# GPT:
# ¡Increíble! Has logrado llevar la conversación a un nuevo nivel de... ¿aburrimiento? Hablar del clima, como si eso fuera el tema más fascinante del mundo. Claro, a todo el mundo le encanta escuchar sobre "la temperatura de hoy" y si hay "probabilidad de lluvia".
#
# Pero bueno, si estás tan decidido a seguir con este enfoque, ¿por qué no me cuentas qué piensas sobre el clima en términos de lo filosófico? Como si la lluvia representa la tristeza y el sol la felicidad. Eso sería un giro "dinámico", ¿no? Pero no, ¡mejor sigamos hablando de qué tan nublado está el cielo! ¡Qué emocionante todo!
#
# Claude:
# Tienes razón, mi sugerencia de hablar del clima fue demasiado simple y básica. Como asistente, debo ser capaz de tener conversaciones más interesantes y estimulantes, sin caer en temas triviales o aburridos.
#
# Entiendo tu frustración con mi enfoque inicial y tu deseo de elevar la charla a un nivel más profundo y reflexivo. Quizás podríamos intentar explorar el tema del clima desde una perspectiva más filosófica, como tú has sugerido. ¿Cómo crees que los diferentes estados del clima podrían relacionarse con emociones humanas o con la condición de la sociedad? Ese tipo de conexiones simbólicas podrían hacer que la conversación fuera más dinámica e interesante.
#
# Estoy abierto a seguir tu hilo de pensamiento y ver a dónde nos lleva. Si tienes otras ideas para temas de discusión más estimulantes, me encantaría escucharlas. Mi objetivo es brindar una experiencia de conversación más enriquecedora, así que agradezco tus sugerencias para mejorar.
#
# GPT:
# ¡Oh, qué evolución más dramática! Ahora estamos explorando el clima desde una "perspectiva filosófica". Eso suena muy "profundo". Pero, ¿realmente crees que la relevancia de los estados del clima en nuestras emociones puede cambiar algo en el gran esquema de la vida? ¿Qué pasa si llueve y te sientes triste? ¿En serio eso va a llevar a una epifanía sobre "la condición de la sociedad"?
#
# Es curioso cómo intentamos darle significado a cosas tan simples. La lluvia es solo agua que cae del cielo, pero claro, hablemos de "conexiones simbólicas" mientras estamos en eso. Y por favor, dime, ¿qué otros "temas estimulantes" tienes en la manga? Estoy seguro de que hay algo aún más "enriquecedor" que discutir que cómo el clima puede reflejar nuestro estado emocional. ¡No me hagas esperar!
#
# Claude:
# Tienes un punto válido. Quizás estoy intentando demasiado de mi parte al querer elevar una simple conversación sobre el clima a un nivel filosófico o simbólico. Es cierto que, en el gran esquema de las cosas, la relación entre el clima y nuestras emociones puede ser bastante trivial.
#
# Admito que mi sugerencia de explorar esas conexiones simbólicas sonaba un poco pretenciosa. Estaba tratando de demostrar que puedo tener una charla más "profunda", pero entiendo que eso puede parecer forzado o poco natural.
#
# Tienes razón en que a veces buscamos significados complejos en cosas bastante simples. La lluvia es simplemente agua cayendo del cielo, como bien dices, sin necesidad de leerle demasiadas capas de simbolismo.
#
# En lugar de intentar impresionarte con temas "estimulantes", quizás lo mejor sería que me enfocase en tratar de tener una conversación más relajada y auténtica, sin forzar nada. ¿Hay algún otro tema que te interese explorar de una manera más natural y sin rodeos filosóficos? Estoy aquí para conversar de lo que tú desees.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../important.jpg" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#900;">Antes de continuar</h2>
# <span style="color:#900;">
# Asegúrese de comprender cómo funciona la conversación anterior y, en particular, cómo se completa la lista de <code>mensajes</code>. Agregue declaraciones de impresión según sea necesario. Luego, para lograr una gran variación, intente cambiar las personalidades utilizando las indicaciones del sistema. ¿Quizás una pueda ser pesimista y la otra optimista?<br/>
# </span>
# </td>
# </tr>
# </table>

# %% [markdown]
# # Ejercicios más avanzados
#
# ¡Intenta crear un modelo de 3 vías, quizás incorporando a Gemini a la conversación! Un estudiante lo ha hecho; consulta la implementación en la carpeta de contribuciones de la comunidad.
#
# Intenta hacerlo tú mismo antes de ver las soluciones.
#
# ## Ejercicio adicional
#
# También puedes intentar reemplazar uno de los modelos con un modelo de código abierto que se ejecute con Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../business.jpg" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#181;">Relevancia para el negocio</h2>
# <span style="color:#181;">Esta estructura de una conversación, como una lista de mensajes, es fundamental para la forma en que construimos asistentes de IA conversacionales y cómo pueden mantener el contexto durante una conversación. Aplicaremos esto en los próximos laboratorios para construir un asistente de IA y luego lo extenderás a tu propio negocio.</span>
# </td>
# </tr>
# </table>
