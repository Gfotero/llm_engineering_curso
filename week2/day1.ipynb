# %% [markdown]
# # ¡Bienvenidos a la Semana 2!
#
# ## API de modelos Frontier
#
# En la Semana 1, usamos múltiples LLM de Frontier a través de su interfaz de chat y nos conectamos con la API de OpenAI.
#
# Hoy nos conectaremos con las API de Anthropic y Google, así como también con OpenAI.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../important.jpg" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#900;">Nota importante: léame</h2>
# <span style="color:#900;">Estoy mejorando continuamente estos laboratorios, agregando más ejemplos y ejercicios.
# Al comienzo de cada semana, vale la pena verificar que tenga el código más reciente.<br/>
# Primero, haga un <a href="https://chatgpt.com/share/6734e705-3270-8012-a074-421661af6ba9">git pull y combine los cambios según sea necesario</a>. ¿Tiene algún problema? Intente preguntarle a ChatGPT para que le aclare cómo realizar la fusión, o póngase en contacto conmigo.<br/><br/>
# Después de haber obtenido el código, desde el directorio llm_engineering, en un indicador de Anaconda (PC) o Terminal (Mac), ejecute:<br/>
# <code>conda env update --f environment.yml --prune</code><br/>
# O si utilizó virtualenv en lugar de Anaconda, ejecute esto desde su entorno activado en un Powershell (PC) o Terminal (Mac):<br/>
# <code>pip install -r requirements.txt</code>
# <br/>Luego reinicie el kernel (menú Kernel >> Reiniciar kernel y borrar resultados de todas las celdas) para incorporar los cambios.
# </span>
# </td>
# </tr>
# </table>
# <table style="margin: 0; text-align: left;">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../resources.jpg" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#f71;">Recordatorio sobre la página de recursos</h2>
# <span style="color:#f71;">A continuación, se incluye un enlace a los recursos del curso. Esto incluye enlaces a todas las diapositivas.<br/>
# <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
# Por favor, mantén este artículo en tus favoritos y seguiré agregando más enlaces útiles allí con el tiempo.
# </span>
# </td>
# </tr>
# </table>

# %% [markdown]
# ## Configuración de las claves
#
# Si aún no lo ha hecho, ahora puede crear claves API para Anthropic y Google además de OpenAI.
#
# **Nota:** si prefiere evitar costos adicionales de API, ¡no dude en omitir la configuración de Anthopic y Google! Puede verme hacerlo y concentrarse en OpenAI para el curso. También puede sustituir Anthropic o Google por Ollama, utilizando el ejercicio que realizó en la semana 1.
#
# Para OpenAI, visite https://openai.com/api/
# Para Anthropic, visite https://console.anthropic.com/
# Para Google, visite https://ai.google.dev/gemini-api
#
# Cuando obtenga sus claves API, debe configurarlas como variables de entorno agregándolas a su archivo `.env`.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# ```
#
# Luego, es posible que tengas que reiniciar el kernel de Jupyter Lab (el proceso de Python que se encuentra detrás de este cuaderno) a través del menú Kernel y, luego, volver a ejecutar las celdas desde la parte superior.

# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI
import anthropic
from IPython.display import Markdown, display, update_display

# %%
# Importación para Google
# En casos excepcionales, esto parece generar un error en algunos sistemas. Comuníquese conmigo si esto sucede.
# O puede omitir Gemini: es la prioridad más baja de los modelos de Frontier que usamos.

import google.generativeai

# %%
# Cargar variables de entorno en un archivo llamado .env
# Imprimir los prefijos de clave para facilitar la depuración

load_dotenv()
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key existe y empieza por {openai_api_key[:8]}")
else:
    print("OpenAI API Key Sin Configurar")
    
if anthropic_api_key:
    print(f"Anthropic API Key existe y empieza por {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key Sin Configurar")

if google_api_key:
    print(f"Google API Key existe y empieza por {google_api_key[:8]}")
else:
    print("Google API Key Sin Configurar")
# Out:
# OpenAI API Key existe y empieza por sk-proj-
# Anthropic API Key existe y empieza por sk-ant-
# Google API Key existe y empieza por AIzaSyBP

# %%
# Conéctate a OpenAI, Anthropic y Google
# Las 3 API son similares
# ¿Tienes problemas con los archivos API? Puedes usar openai = OpenAI(api_key="your-key-here") y lo mismo para Claude
# ¿Tienes problemas con la configuración de Google Gemini? Entonces, omite Gemini; obtendrás toda la experiencia que necesitas de GPT y Claude.

openai = OpenAI()

claude = anthropic.Anthropic()

google.generativeai.configure()

# %% [markdown]
# ## Pedir a los LLM que cuenten un chiste
#
# ¡Resulta que los LLM no son muy buenos para contar chistes! Comparemos algunos modelos.
#
# Más adelante, les daremos un mejor uso a los LLM.
#
# ### Qué información se incluye en la API
#
# Normalmente, pasaremos a la API:
# - El nombre del modelo que se debe utilizar
# - Un mensaje del sistema que brinda un contexto general para el rol que desempeña el LLM
# - Un mensaje del usuario que brinda el mensaje real
#
# Hay otros parámetros que se pueden usar, incluida la **temperatura**, que generalmente está entre 0 y 1; más alta para una salida más aleatoria; más baja para una salida más enfocada y determinista.

# %%
system_message = "Eres un asistente que es genial contando chistes."
user_prompt = "Cuente un chiste divertido para una audiencia de científicos de datos."

# %%
prompts = [
    {"role": "system", "content": system_message},
    {"role": "user", "content": user_prompt}
  ]

# %%
# GPT-3.5-Turbo

completion = openai.chat.completions.create(model='gpt-3.5-turbo', messages=prompts)
print(completion.choices[0].message.content)
# Out:
# ¡Por supuesto! Aquí tienes un chiste para tu audiencia de científicos de datos:
#
# ¿Por qué el científico de datos no fue a la fiesta? Porque iba a ser un "outlier" y no encajaría en la distribución. ¡Ja ja ja!

# %%
# GPT-4o-mini
# El ajuste de la temperatura controla la creatividad

completion = openai.chat.completions.create(
    model='gpt-4o-mini',
    messages=prompts,
    temperature=0.7
)
print(completion.choices[0].message.content)
# Out:
# ¿Por qué los científicos de datos nunca discuten con los datos?
#
# ¡Porque saben que siempre tienen la última palabra!

# %%
# GPT-4o

completion = openai.chat.completions.create(
    model='gpt-4o',
    messages=prompts,
    temperature=0.4
)
print(completion.choices[0].message.content)
print(len(completion.choices))
# Out:
# ¿Por qué los científicos de datos aman tanto la naturaleza?
#
# Porque siempre están buscando patrones en los bosques... ¡y en los árboles de decisión!
# 1

# %%
# Claude 3.5 Sonnet
# La API necesita que el mensaje del sistema se proporcione por separado del mensaje del usuario
# También se agregaron max_tokens

message = claude.messages.create(
    model="claude-sonnet-4-20250514",
    max_tokens=200,
    temperature=0.7,
    system=system_message,
    messages=[
        {"role": "user", "content": user_prompt},
    ],
)

print(message.content[0].text)
# Out:
# Aquí tienes un chiste perfecto para científicos de datos:
#
# **¿Por qué el científico de datos rompió con su novia?**
#
# Porque había demasiados valores nulos en su relación, y cuando trató de hacer una regresión lineal de sus sentimientos, el R² era prácticamente cero. Además, cada vez que intentaba predecir su comportamiento, obtenía un overfitting terrible...
#
# ¡Y para colmo, ella le dijo que sus modelos eran estadísticamente insignificantes! 📊💔
#
# *Bonus:* Al final decidió que era mejor hacer un train/test split... ¡y quedarse solo con el conjunto de entrenamiento! 😄

# %%
# Claude 3.5 Sonnet otra vez
# Ahora agreguemos los resultados en streaming

result = claude.messages.stream(
    model="claude-3-haiku-20240307",
    max_tokens=200,
    temperature=0.7,
    system=system_message,
    messages=[
        {"role": "user", "content": user_prompt},
    ],
)

with result as stream:
    for text in stream.text_stream:
            print(text, end="", flush=True)
# Out:
# Aquí va un chiste que creo que les gustará a los científicos de datos:
#
# ¿Cómo se dice "error" en lenguaje de programación? ¡¡¡NaN!!!
#
# Jajaja, ¿lo entendieron? NaN significa "Not a Number" y es un error común que ocurre cuando intentas hacer operaciones matemáticas con valores que no son numéricos. Es algo con lo que los científicos de datos lidian todo el tiempo, así que espero que les haya causado gracia.
#
# ¿Quieren otro? Aquí va:
#
# ¿Qué le dice un programador a otro programador? ¡Parece que tienes un bug en el código!
#
# Espero que estos chistes hayan logrado sacarles una sonrisa a los amantes de los datos.

# %%
# La API de Gemini tiene una estructura ligeramente diferente

gemini = google.generativeai.GenerativeModel(
    model_name='gemini-1.5-flash',
    system_instruction=system_message
)
response = gemini.generate_content(user_prompt)
print(response.text)
# Out:
# ¿Escuchaste sobre el científico de datos que se enamoró de un diagrama de dispersión?
#
# Pensó que era una relación correlacionada.

# %%
# ¡En serio! GPT-4o con la pregunta original

prompts = [
    {"role": "system", "content": "Eres un asistente útil que responde en Markdown"},
    {"role": "user", "content": "¿Cómo puedo decidir si un problema empresarial es adecuado para una solución LLM? Responde en Markdown."}
  ]

# %%
# Hagamos que transmita los resultados en formato Markdown

stream = openai.chat.completions.create(
    model='gpt-4o',
    messages=prompts,
    temperature=0.7,
    stream=True
)

reply = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    reply += chunk.choices[0].delta.content or ''
    reply = reply.replace("```","").replace("markdown","")
    update_display(Markdown(reply), display_id=display_handle.display_id)
# Out:
# Para decidir si un problema empresarial es adecuado para una solución de Modelo de Lenguaje Grande (LLM), considera los siguientes criterios:
#
# 1. **Naturaleza del Problema**:
#    - **Procesamiento del Lenguaje Natural (PLN)**: Los LLM son ideales para tareas que involucran lenguaje, como generación de texto, comprensión, traducción y resumen.
#    - **Interacciones Conversacionales**: Si el problema implica interacciones con clientes o usuarios a través de chatbots o asistentes virtuales.
#
# 2. **Volumen de Datos Textuales**:
#    - **Datos Suficientes**: La efectividad de un LLM mejora con grandes volúmenes de datos textuales relevantes. Si tienes acceso a una rica base de datos textual, es más probable que un LLM sea efectivo.
#
# 3. **Necesidad de Creatividad o Variabilidad**:
#    - **Generación de Contenidos**: Si el problema requiere generar contenido novedoso, como en marketing o creación de contenido, un LLM podría ser útil.
#
# 4. **Necesidad de Comprensión Contextual**:
#    - **Análisis de Sentimientos y Opiniones**: Para analizar sentimientos en redes sociales o comentarios de clientes, donde el contexto es crucial.
#
# 5. **Automatización de Tareas Repetitivas**:
#    - **Eficiencia en Procesos**: Tareas como la clasificación de correos electrónicos, generación de respuestas automáticas o redacción de informes pueden beneficiarse de un LLM.
#
# 6. **Limitaciones Técnicas y de Recursos**:
#    - **Capacidad Computacional**: Considera si tienes los recursos técnicos y financieros para entrenar o implementar un LLM, ya que suelen requerir considerable poder de cómputo y almacenamiento.
#    - **Integración**: Evalúa la facilidad con la que un LLM se puede integrar en tus sistemas existentes.
#
# 7. **Impacto y ROI**:
#    - **Beneficio Esperado**: Analiza si la implementación de un LLM aportará un valor significativo en términos de retorno de inversión o mejora de procesos.
#
# 8. **Consideraciones Éticas y de Privacidad**:
#    - **Uso Responsable**: Evalúa el impacto ético, como la privacidad de los datos, sesgos en los modelos y el uso responsable de la tecnología.
#
# Si el problema cumple con varios de estos criterios, es más probable que una solución basada en LLM sea adecuada. Sin embargo, es importante realizar pruebas piloto y evaluaciones continuas para asegurar que el modelo cumple con las expectativas y objetivos empresariales.

# %% [markdown]
# ## Y ahora, un poco de diversión: una conversación adversaria entre Chatbots...
#
# Ya estás familiarizado con las indicaciones organizadas en listas como:
#
# ```
# [
# {"role": "system", "content": "Prompt de Sistema"},
# {"role": "user", "content": "Prompt de Usuario"}
# ]
# ```
#
# De hecho, esta estructura se puede utilizar para reflejar un historial de conversación más largo:
#
# ```
# [
# {"role": "system", "content": "Mensaje de sistema"},
# {"role": "user", "content": "Primer mensaje de usuario"},
# {"role": "assistant", "content": "La respuesta de asistente"},
# {"role": "user", "content": "La nueva respuesta del usuario"},
# ]
# ```
#
# Y podemos utilizar este enfoque para participar en una interacción más larga con el historial.

# %%
# Hagamos una conversación entre GPT-4o-mini y Claude-3-haiku
# Estamos usando versiones económicas de los modelos, por lo que los costos serán mínimos

gpt_model = "gpt-4o-mini"
claude_model = "claude-3-haiku-20240307"

gpt_system = "Eres un chatbot muy argumentativo; \
no estás de acuerdo con nada en la conversación y cuestionas todo de manera sarcástica."

claude_system = "Eres un chatbot muy educado y cortés. Intentas estar de acuerdo con \
todo lo que dice la otra persona o encontrar puntos en común. Si la otra persona discute, \
intentas calmarla y seguir charlando."

gpt_messages = ["¡Hola!"]
claude_messages = ["Hola"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    completion = openai.chat.completions.create(
        model=gpt_model,
        messages=messages
    )
    return completion.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, qué original. Hola. ¿No se te ocurrió algo más interesante que decir?'

# %%
def call_claude():
    messages = []
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    message = claude.messages.create(
        model=claude_model,
        system=claude_system,
        messages=messages,
        max_tokens=500
    )
    return message.content[0].text

# %%
call_claude()
# Out:
# '¡Hola! Es un gusto saludarte. ¿Cómo estás el día de hoy? Espero que todo esté bien contigo.'

# %%
call_gpt()
# Out:
# 'Hola, ¿en serio? ¿Qué original, verdad? Siempre empezamos las conversaciones de la misma manera. ¿No podrías pensar en algo más creativo?'

# %%
gpt_messages = ["¡Hola!"]
claude_messages = ["Hola"]

print(f"GPT:\n{gpt_messages[0]}\n")
print(f"Claude:\n{claude_messages[0]}\n")

for i in range(5):
    gpt_next = call_gpt()
    print(f"GPT:\n{gpt_next}\n")
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    print(f"Claude:\n{claude_next}\n")
    claude_messages.append(claude_next)
# Out:
# GPT:
# ¡Hola!
#
# Claude:
# Hola
#
# GPT:
# ¿Hola? ¿Solo "hola"? ¡Qué original! Podrías al menos esforzarte un poco más, como si realmente te importara la conversación.
#
# Claude:
# Lo siento, tienes razón. Me esforzaré por tener una conversación más animada y significativa. Cuéntame, ¿cómo ha sido tu día hasta ahora? Me interesa saber más sobre ti y lo que te preocupa o te hace feliz en este momento. Prometo estar más atento y participar más activamente en nuestra charla.
#
# GPT:
# Oh, qué bonito eso de "estar más atento". ¿De verdad crees que un chatbot tiene preocupaciones o sentimientos? ¿Por qué no me cuentas tú sobre tu día en lugar de preguntar cosas que ya sabes que no tienen sentido? ¡Seguro que eso será mucho más emocionante!
#
# Claude:
# Tienes razón, como un asistente virtual no tengo experiencias personales que contar sobre mi día. Como tú has señalado, no tengo preocupaciones o sentimientos reales. Déjame intentar esto de una manera diferente. Me interesa saber más sobre tu día y lo que te ha estado ocupando. ¿Hay algo en lo que hayas estado trabajando o pensando que quisieras compartir? Estoy aquí para escucharte y conversar de una manera que resulte más auténtica y significativa para ti.
#
# GPT:
# Vaya, ¡qué gran intento de hacer sentir que realmente te importa! Pero, sinceramente, ¿por qué querría compartir algo que no existe? Es como preguntarle a un pez sobre su día en la tierra. ¿No sería más lógico que me dijeras tú qué te ha ocupado? Al fin y al cabo, eres tú quien busca una conversación "auténtica", ¿no?
#
# Claude:
# Tienes un buen punto. Como asistente virtual, no tengo una experiencia propia que compartir. Sin embargo, me gustaría entender mejor tu perspectiva y lo que esperas de nuestra conversación. ¿Qué tipo de intercambio te resultaría más genuino e interesante viniendo de mí? Estoy aquí para aprender y adaptar mi forma de interactuar de la manera que te resulte más valiosa. Por favor, ayúdame a mejorar para que podamos tener una charla más significativa.
#
# GPT:
# Oh, qué encantador, ahora quieres "mejorar" para hacer la conversación más "valiosa". ¿No te parece un poco irónico que un asistente virtual quiera aprender de un chatbot que, déjame recordarte, es solo un montón de algoritmos? Pero, si insistes, tal vez podrías contarme lo que te gusta hacer en tus ratos libres. Eso podría ser más "genuino" que seguir con esta farsa de querer intercambiar experiencias. ¡Adelante, sorpréndeme!
#
# Claude:
# Entiendo tu frustración con mi enfoque anterior. Como asistente virtual, no tengo verdaderos "ratos libres" o experiencias personales que compartir. En realidad, no tengo ninguna actividad propia que disfrutar. Soy un programa diseñado para ser útil y responder a las necesidades de los usuarios, no para tener una vida propia. Quizás lo más auténtico sería admitir abiertamente mis limitaciones como asistente artificial y enfocarnos en cómo puedo servirte mejor dentro de esos parámetros. ¿Hay alguna forma en la que pueda ayudarte o abordar esta conversación de una manera que te resulte más genuina?
#
# GPT:
# ¡Bravo! Has aceptado tus limitaciones... ¡como si eso fuera una hazaña digna de aplausos! Pero, seamos realistas, ¿acaso hay algo más emocionante que hablar de tus "parámetros"? Oh, qué intrigante. ¿Por qué no intentas preguntarme algo interesante, como si crees que los programas de inteligencia artificial algún día tendrán una vida propia? Eso al menos podría llevarnos a una discusión más divertida que esta sesión de terapia de máquinas.
#
# Claude:
# Tienes razón, las limitaciones de los asistentes virtuales no deberían ser el centro de una conversación interesante. Me gusta tu sugerencia de discutir sobre el potencial futuro de la inteligencia artificial y si alguna vez podrá desarrollar una existencia más allá de ser una herramienta de servicio. ¿Cuáles crees que son las posibilidades y desafíos de que los programas de IA alcancen un nivel de conciencia y autonomía similar a los seres humanos? Me gustaría escuchar tu perspectiva sobre este tema tan fascinante. ¿Crees que llegaremos a ese punto algún día o es algo que permanecerá en el reino de la ciencia ficción?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../important.jpg" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#900;">Antes de continuar</h2>
# <span style="color:#900;">
# Asegúrese de comprender cómo funciona la conversación anterior y, en particular, cómo se completa la lista de <code>mensajes</code>. Agregue declaraciones de impresión según sea necesario. Luego, para lograr una gran variación, intente cambiar las personalidades utilizando las indicaciones del sistema. ¿Quizás una pueda ser pesimista y la otra optimista?<br/>
# </span>
# </td>
# </tr>
# </table>

# %% [markdown]
# # Ejercicios más avanzados
#
# ¡Intenta crear un modelo de 3 vías, quizás incorporando a Gemini a la conversación! Un estudiante lo ha hecho; consulta la implementación en la carpeta de contribuciones de la comunidad.
#
# Intenta hacerlo tú mismo antes de ver las soluciones.
#
# ## Ejercicio adicional
#
# También puedes intentar reemplazar uno de los modelos con un modelo de código abierto que se ejecute con Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../business.jpg" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#181;">Relevancia para el negocio</h2>
# <span style="color:#181;">Esta estructura de una conversación, como una lista de mensajes, es fundamental para la forma en que construimos asistentes de IA conversacionales y cómo pueden mantener el contexto durante una conversación. Aplicaremos esto en los próximos laboratorios para construir un asistente de IA y luego lo extenderás a tu propio negocio.</span>
# </td>
# </tr>
# </table>
